# %%
import numpy as np
import pandas as pd

# %%
s1 = np.random.rand(4)
s2 = np.random.rand(4)
s3 = np.random.rand(4)
s4 = np.random.rand(4)

# %%
s1
# Out:
# array([0.43782504, 0.15290392, 0.51155791, 0.23187187])

# %%
s2
# Out:
# array([0.89496463, 0.00953099, 0.37244632, 0.79540465])

# %%
s3
# Out:
# array([0.33610909, 0.05593567, 0.37587487, 0.56760307])

# %%
s4
# Out:
# array([0.79334508, 0.11927958, 0.06848108, 0.64744336])

# %%
df = pd.DataFrame([s1,s2,s3,s4])

# %%
df
# Out:
#           0         1         2         3
# 0  0.437825  0.152904  0.511558  0.231872
# 1  0.894965  0.009531  0.372446  0.795405
# 2  0.336109  0.055936  0.375875  0.567603
# 3  0.793345  0.119280  0.068481  0.647443

# %%
df = df.T

# %%
df
# Out:
#           0         1         2         3
# 0  0.437825  0.894965  0.336109  0.793345
# 1  0.152904  0.009531  0.055936  0.119280
# 2  0.511558  0.372446  0.375875  0.068481
# 3  0.231872  0.795405  0.567603  0.647443

# %%
df = df.T

# %%
df
# Out:
#           0         1         2         3
# 0  0.437825  0.152904  0.511558  0.231872
# 1  0.894965  0.009531  0.372446  0.795405
# 2  0.336109  0.055936  0.375875  0.567603
# 3  0.793345  0.119280  0.068481  0.647443

# %%
df.columns = (['Random Value 1', 'Random Value 2', 'Random Value 3', 'Random Value 4'])

# %%
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0        0.437825        0.152904        0.511558        0.231872
# 1        0.894965        0.009531        0.372446        0.795405
# 2        0.336109        0.055936        0.375875        0.567603
# 3        0.793345        0.119280        0.068481        0.647443

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.615561        0.084413        0.332090        0.560581
# std          0.270405        0.064096        0.187300        0.238597
# min          0.336109        0.009531        0.068481        0.231872
# 25%          0.412396        0.044335        0.296455        0.483670
# 50%          0.615585        0.087608        0.374161        0.607523
# 75%          0.818750        0.127686        0.409796        0.684434
# max          0.894965        0.152904        0.511558        0.795405

# %%
df.isnull()
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
for i in df.columns:
  print(i, df[i].dtype)
# Out:
# Random Value 1 float64
# Random Value 2 float64
# Random Value 3 float64
# Random Value 4 float64

# %%
df.loc[0:, 'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0        0.152904        0.511558
# 1        0.009531        0.372446
# 2        0.055936        0.375875
# 3        0.119280        0.068481

# %%
df.iloc[0:, 1:3]
# Out:
#    Random Value 2  Random Value 3
# 0        0.152904        0.511558
# 1        0.009531        0.372446
# 2        0.055936        0.375875
# 3        0.119280        0.068481
